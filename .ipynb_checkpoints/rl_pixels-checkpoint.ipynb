# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
import tensorflow as tf
from IPython.display import clear_output
from ipywidgets import interact

plt.ion()

# %%
def arm(dim, t1, target_point):
    #img = np.zeros((dim, dim))
    img = np.random.random_sample((dim, dim)) * .3 - .15
    l = dim*.5
    x, y = int(dim/2), int(dim/2)
    xp, yp = x + int(np.cos(t1)*l), y + int(np.sin(t1)*l)
    dist = np.sqrt(np.square(np.cos(t1) - target_point[0]) + np.square(np.sin(t1) - target_point[1]))
    cv2.line(img, (x, y), (xp, yp), (1,1,1))
    return img, dist

# %%
def graph(t1):
    data, dist = arm(8, t1, (1,0))
    print(dist)
    plt.imshow(np.flipud(data), cmap=plt.cm.gray, interpolation='nearest')
    
interact(graph, t1=(0, 2*np.pi, .1))
# Out:
# 1.98542598208
# <function __main__.graph>

# %%
def plot_avs(res=30):
    avs = []
    T = np.linspace(0, np.pi * 2.0, res)
    for t1 in T:
        data, dist = arm(DIM, t1, (0, 0))
        action_vals = y.eval(feed_dict={x: data.reshape((IN, 1))})
        avs.append(action_vals)

    avs = np.array(avs)
    plt.plot(T, avs[:,0], c='b')
    plt.plot(T, avs[:,1], c='r')

# %%
# Define network to predict action values
DIM = 16
IN = DIM**2
HIDDEN = 30
OUT = 2
ACTIONS = 2
GAMMA = 0.9

x = tf.placeholder(tf.float32, (IN, 1))

W1 = tf.Variable(tf.random_normal((HIDDEN, IN)))
b1 = tf.Variable(tf.random_normal((HIDDEN, 1)))

W2 = tf.Variable(tf.random_normal((OUT, HIDDEN)))
b2 = tf.Variable(tf.random_normal((OUT, 1)))

h1 = tf.nn.tanh(tf.matmul(W1, x) + b1)
y = tf.matmul(W2, h1) + b2

t = tf.placeholder(tf.float32, (OUT, 1))

cost = tf.reduce_mean(tf.square(t - y))

# %%
if 'session' in globals():
    session.close()

session = tf.InteractiveSession()
session.run(tf.initialize_all_variables())

# %%
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
costs = []
t1s = []

def perform_action(theta, action_id):
    return theta + (action_id*2.0 - 1.0) * np.pi/8.0 # rotate left or right

for i in range(10000):
    target_point = (1, 0)
    
    t1 = np.random.random_sample() * np.pi * 2.0
    
    data1, dist1 = arm(DIM, t1, target_point)
    
    rand_action = np.random.randint(ACTIONS)
    
    t1 = perform_action(t1, rand_action)
    
    t1s.append(t1)
    
    data2, dist2 = arm(DIM, t1, target_point)
    
    reward = (dist1 - dist2) / 2.0 - .5
    
    action_values = y.eval(feed_dict={x: data1.reshape((IN, 1))})
    action_values_p = y.eval(feed_dict={x: data2.reshape((IN, 1))})
    
    max_q = np.max(action_values_p)
    
    target_action_values = np.full_like(action_values, max_q) * GAMMA
    target_action_values[rand_action, 0] += reward
    
    session.run(train, feed_dict={x: data1.reshape((IN, 1)), t: target_action_values})
    
    if i%1000==0:
        clear_output(wait=True)
        c = cost.eval(feed_dict={x: data1.reshape((IN, 1)), t: target_action_values})
        print(c)
        plot_avs(res=16)
        plt.show()
        costs.append(c)
# Out:
# 0.0044889

# %%
plot_avs(res=16)

# %%
plt.imshow(W1.eval(session), cmap=plt.cm.gray, interpolation='nearest')

# %%
# Rollout of agent's behavior!

from matplotlib import gridspec

t1 = np.random.random_sample() * np.pi * 2.0

for i in range(200):
    data, _ = arm(DIM, t1, (1, 0))
    action_values = y.eval(feed_dict={x: data.reshape((IN, 1))})
    best_action = np.argmax(action_values)
    
    # perform best action
    t1 = perform_action(t1, best_action)
    
    data_p, dist = arm(DIM, t1, (1, 0))
    
    clear_output(wait=True)
    #print(action_values, np.argmax(action_values))
    gs = gridspec.GridSpec(1, 2)
    plt.figure(figsize=(16,4))
    
    plt.subplot(gs[0])
    plt.axis('off')
    plt.imshow(data_p, interpolation='nearest', cmap=plt.cm.gray)
    
    h1_act = h1.eval(feed_dict={x: data.reshape((IN, 1))})
    
    plt.subplot(gs[1])
    plt.scatter(range(len(h1_act)), h1_act)
    
    #plt.subplot(gs[1])
    #plt.axis('off')
    #plt.plot(action_values)
    
    plt.show()
    
    if dist < 0.2:
        t1 = np.random.random_sample() * np.pi * 2.0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-a91cbc9e35ac> in <module>()
#      20     plt.figure(figsize=(16,4))
#      21
# ---> 22     plt.subplot(gs[0])
#      23     plt.axis('off')
#      24     plt.imshow(data_p, interpolation='nearest', cmap=plt.cm.gray)
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1020
#    1021     fig = gcf()
# -> 1022     a = fig.add_subplot(*args, **kwargs)
#    1023     bbox = a.bbox
#    1024     byebye = []
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1003                     self._axstack.remove(ax)
#    1004
# -> 1005             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1006
#    1007         self._axstack.add(key, a)
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     506
#     507         # this call may differ for non-sep axes, e.g., polar
# --> 508         self._init_axis()
#     509
#     510         if axisbg is None:
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/axes/_base.py in _init_axis(self)
#     567         self.spines['bottom'].register_axis(self.xaxis)
#     568         self.spines['top'].register_axis(self.xaxis)
# --> 569         self.yaxis = maxis.YAxis(self)
#     570         self.spines['left'].register_axis(self.yaxis)
#     571         self.spines['right'].register_axis(self.yaxis)
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/axis.py in __init__(self, axes, pickradius)
#     656         self._minor_tick_kw = dict()
#     657
# --> 658         self.cla()
#     659         self._set_scale('linear')
#     660
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/axis.py in cla(self)
#     740         self._set_artist_props(self.label)
#     741
# --> 742         self.reset_ticks()
#     743
#     744         self.converter = None
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/axis.py in reset_ticks(self)
#     755
#     756         self.majorTicks.extend([self._get_tick(major=True)])
# --> 757         self.minorTicks.extend([self._get_tick(major=False)])
#     758         self._lastNumMajorTicks = 1
#     759         self._lastNumMinorTicks = 1
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1998         else:
#    1999             tick_kw = self._minor_tick_kw
# -> 2000         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2001
#    2002     def _get_label(self):
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     149
#     150         self.tick1line = self._get_tick1line()
# --> 151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#     153
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     550                           markersize=self._size,
#     551                           markeredgewidth=self._width,
# --> 552                           zorder=self._zorder)
#     553         l.set_transform(self.axes.get_yaxis_transform(which='tick2'))
#     554         self._set_artist_props(l)
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     336         self._color = None
#     337         self.set_color(color)
# --> 338         self._marker = MarkerStyle()
#     339         self.set_marker(marker)
#     340
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     170         self._fillstyle = fillstyle
#     171         self.set_marker(marker)
# --> 172         self.set_fillstyle(fillstyle)
#     173
#     174     def __getstate__(self):
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/markers.py in set_fillstyle(self, fillstyle)
#     220                              % ' '.join(self.fillstyles))
#     221         self._fillstyle = fillstyle
# --> 222         self._recache()
#     223
#     224     def get_joinstyle(self):
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/markers.py in _recache(self)
#     183
#     184     def _recache(self):
# --> 185         self._path = Path(np.empty((0, 2)))
#     186         self._transform = IdentityTransform()
#     187         self._alt_path = None
#
# /Users/joncomo/miniconda2/envs/py34/lib/python3.4/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     159         self._vertices = vertices
#     160         self._codes = codes
# --> 161         self._interpolation_steps = _interpolation_steps
#     162         self._update_values()
#     163
#
# KeyboardInterrupt:
